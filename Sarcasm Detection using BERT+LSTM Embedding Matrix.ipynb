# %% [markdown]
# # Importing Necessary Libraries

# %%
import numpy as np 
import pandas as pd 
import os
import re
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, GRU, LSTM, Bidirectional,Conv1D,MaxPooling1D,Flatten,Dropout
from keras.initializers import Constant
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
import tensorflow_hub as hub
import tensorflow_text as text

# %% [markdown]
# # Importing Dataset

# %%
data_1 = pd.read_json("Sarcasm_Headlines_Dataset.json", lines=True)
data_2 = pd.read_json("Sarcasm_Headlines_Dataset_v2.json", lines=True)
data =  pd.concat([data_1, data_2])
data.head()
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
#
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0

# %% [markdown]
# # Text Cleaning & Preprocessing

# %%
def clean_text(text):
    text = text.lower()
    pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    text = pattern.sub('', text)
    text = " ".join(filter(lambda x:x[0]!='@', text.split()))
    emoji = re.compile("["
                           u"\U0001F600-\U0001FFFF"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    
    text = emoji.sub(r'', text)
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)        
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text) 
    text = re.sub(r"\'ll", " will", text)  
    text = re.sub(r"\'ve", " have", text)  
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"don't", "do not", text)
    text = re.sub(r"did't", "did not", text)
    text = re.sub(r"can't", "can not", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"couldn't", "could not", text)
    text = re.sub(r"have't", "have not", text)
    text = re.sub(r"[,.\"\'!@#$%^&*(){}?/;`~:<>+=-]", "", text)
    return text

# %%
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk
nltk.download('punkt')
nltk.download('stopwords')

def CleanTokenize(df):
    head_lines = list()
    lines = df["headline"].values.tolist()

    for line in lines:
        line = clean_text(line)
        # tokenize the text
        tokens = word_tokenize(line)
        # remove puntuations
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in tokens]
        # remove non alphabetic characters
        words = [word for word in stripped if word.isalpha()]
        stop_words = set(stopwords.words("english"))
        # remove stop words
        words = [w for w in words if not w in stop_words]
        head_lines.append(words)
    return head_lines

head_lines = CleanTokenize(data)
head_lines[0:10]
# Out:
# [nltk_data] Downloading package punkt to /home/intern1/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/intern1/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [['former',
#   'versace',
#   'store',
#   'clerk',
#   'sues',
#   'secret',
#   'black',
#   'code',
#   'minority',
#   'shoppers'],
#  ['roseanne',
#   'revival',
#   'catches',
#   'thorny',
#   'political',
#   'mood',
#   'better',
#   'worse'],
#  ['mom',
#   'starting',
#   'fear',
#   'sons',
#   'web',
#   'series',
#   'closest',
#   'thing',
#   'grandchild'],
#  ['boehner',
#   'wants',
#   'wife',
#   'listen',
#   'come',
#   'alternative',
#   'debtreduction',
#   'ideas'],
#  ['jk', 'rowling', 'wishes', 'snape', 'happy', 'birthday', 'magical', 'way'],
#  ['advancing', 'worlds', 'women'],
#  ['fascinating', 'case', 'eating', 'labgrown', 'meat'],
#  ['ceo', 'send', 'kids', 'school', 'work', 'company'],
#  ['top', 'snake', 'handler', 'leaves', 'sinking', 'huckabee', 'campaign'],
#  ['fridays', 'morning', 'email', 'inside', 'trumps', 'presser', 'ages']]

# %% [markdown]
# # Train Test Split the Data

# %%
validation_split = 0.2
max_length = 30 #when set to Mximum length ..doesnt give a good efficiency


tokenizer_obj = Tokenizer()
tokenizer_obj.fit_on_texts(head_lines)
sequences = tokenizer_obj.texts_to_sequences(head_lines)

word_index = tokenizer_obj.word_index
print("unique tokens - ",len(word_index))
vocab_size = len(tokenizer_obj.word_index) + 1
print('vocab size -', vocab_size)

lines_pad = pad_sequences(sequences, maxlen=max_length, padding='post')
sentiment =  data['is_sarcastic'].values

indices = np.arange(lines_pad.shape[0])
np.random.shuffle(indices)
lines_pad = lines_pad[indices]
sentiment = sentiment[indices]

num_validation_samples = int(validation_split * lines_pad.shape[0])

X_train_pad = lines_pad[:-num_validation_samples]
y_train = sentiment[:-num_validation_samples]
X_test_pad = lines_pad[-num_validation_samples:]
y_test = sentiment[-num_validation_samples:]
# Out:
# unique tokens -  28657
# vocab size - 28658

# %%
print('Shape of X_train_pad:', X_train_pad.shape)
print('Shape of y_train:', y_train.shape)

print('Shape of X_test_pad:', X_test_pad.shape)
print('Shape of y_test:', y_test.shape)
# Out:
# Shape of X_train_pad: (44263, 30)
# Shape of y_train: (44263,)
# Shape of X_test_pad: (11065, 30)
# Shape of y_test: (11065,)

# %% [markdown]
# # Loading BERT Preprocess & Base Model from Tensorflow

# %%
preprocess_url = 'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3'
encoder_url = 'https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4'

# %%
bert_preprocess_model = hub.KerasLayer(preprocess_url)

# %%
text_test = ['Very bad movie','I love Python']
text_preprocessed = bert_preprocess_model(text_test)
text_preprocessed.keys()
# Out:
# dict_keys(['input_word_ids', 'input_mask', 'input_type_ids'])

# %%
bert_model = hub.KerasLayer(encoder_url)

# %%
bert_results = bert_model(text_preprocessed)
bert_results.keys()
# Out:
# dict_keys(['default', 'pooled_output', 'encoder_outputs', 'sequence_output'])

# %%
def get_word_embedding(word):
    text_preprocessed = bert_preprocess_model([word])
    bert_results = bert_model(text_preprocessed)
    return np.array(bert_results['pooled_output'][0])

# %%
get_word_embedding("snake").shape
# Out:
# (768,)

# %% [markdown]
# # Determine the max_length of sentence in the corpus

# %%
all_lengths = [len(x) for x in head_lines]

# %%
max_length_sentence = max(all_lengths)

# %%
max_length_sentence
# Out:
# 106

# %% [markdown]
# # Train_Test_Split

# %%
validation_split = 0.2
max_length = 25 #when set to Mximum length ..doesnt give a good efficiency


tokenizer_obj = Tokenizer()
tokenizer_obj.fit_on_texts(head_lines)
sequences = tokenizer_obj.texts_to_sequences(head_lines)

word_index = tokenizer_obj.word_index
print("unique tokens - ",len(word_index))
vocab_size = len(tokenizer_obj.word_index) + 1
print('vocab size -', vocab_size)

lines_pad = pad_sequences(sequences, maxlen=max_length, padding='post')
sentiment =  data['is_sarcastic'].values

indices = np.arange(lines_pad.shape[0])
np.random.shuffle(indices)
lines_pad = lines_pad[indices]
sentiment = sentiment[indices]

num_validation_samples = int(validation_split * lines_pad.shape[0])

X_train_pad = lines_pad[:-num_validation_samples]
y_train = sentiment[:-num_validation_samples]
X_test_pad = lines_pad[-num_validation_samples:]
y_test = sentiment[-num_validation_samples:]
# Out:
# unique tokens -  28657
# vocab size - 28658

# %%
print('Shape of X_train_pad:', X_train_pad.shape)
print('Shape of y_train:', y_train.shape)

print('Shape of X_test_pad:', X_test_pad.shape)
print('Shape of y_test:', y_test.shape)
# Out:
# Shape of X_train_pad: (44263, 25)
# Shape of y_train: (44263,)
# Shape of X_test_pad: (11065, 25)
# Shape of y_test: (11065,)

# %% [markdown]
# # Creating Embedding BERT Matrix + Layer

# %%
embedding_dim = 768
embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
c = 0
for word, i in word_index.items():
    print(f"=========================={i}th iteration=========================")
#     embedding_vector = embeddings_index.get(word)
    try:
        embedding_vector = get_word_embedding(word)
    except:
        embedding_vector = None
    if embedding_vector is not None:
        c+=1
        embedding_matrix[i] = embedding_vector
    
print(c)
# Out:
# ==========================1th iteration=========================
# ==========================2th iteration=========================
# ==========================3th iteration=========================
# ==========================4th iteration=========================
# ==========================5th iteration=========================
# ==========================6th iteration=========================
# ==========================7th iteration=========================
# ==========================8th iteration=========================
# ==========================9th iteration=========================
# ==========================10th iteration=========================
# ==========================11th iteration=========================
# ==========================12th iteration=========================
# ==========================13th iteration=========================
# ==========================14th iteration=========================
# ==========================15th iteration=========================
# ==========================16th iteration=========================
# ==========================17th iteration=========================
# ==========================18th iteration=========================
# ==========================19th iteration=========================
# ==========================20th iteration=========================
# ==========================21th iteration=========================
# ==========================22th iteration=========================
# ==========================23th iteration=========================
# ==========================24th iteration=========================
# ==========================25th iteration=========================
# ==========================26th iteration=========================
# ==========================27th iteration=========================
# ==========================28th iteration=========================
# ==========================29th iteration=========================
# ==========================30th iteration=========================
# ==========================31th iteration=========================
# ==========================32th iteration=========================
# ==========================33th iteration=========================
# ==========================34th iteration=========================
# ==========================35th iteration=========================
# ==========================36th iteration=========================
# ==========================37th iteration=========================
# ==========================38th iteration=========================
# ==========================39th iteration=========================
# ==========================40th iteration=========================
# ==========================41th iteration=========================
# ==========================42th iteration=========================
# ==========================43th iteration=========================
# ==========================44th iteration=========================
# ==========================45th iteration=========================
# ==========================46th iteration=========================
# ==========================47th iteration=========================
# ==========================48th iteration=========================
# ==========================49th iteration=========================
# ==========================50th iteration=========================
# ==========================51th iteration=========================
# ==========================52th iteration=========================
# ==========================53th iteration=========================
# ==========================54th iteration=========================
# ==========================55th iteration=========================
# ==========================56th iteration=========================
# ==========================57th iteration=========================
# ==========================58th iteration=========================
# ==========================59th iteration=========================
# ==========================60th iteration=========================
# ==========================61th iteration=========================
# ==========================62th iteration=========================
# ==========================63th iteration=========================
# ==========================64th iteration=========================
# ==========================65th iteration=========================
# ==========================66th iteration=========================
# ==========================67th iteration=========================
# ==========================68th iteration=========================
# ==========================69th iteration=========================
# ==========================70th iteration=========================
# ==========================71th iteration=========================
# ==========================72th iteration=========================
# ==========================73th iteration=========================
# ==========================74th iteration=========================
# ==========================75th iteration=========================
# ==========================76th iteration=========================
# ==========================77th iteration=========================
# ==========================78th iteration=========================
# ==========================79th iteration=========================
# ==========================80th iteration=========================
# ==========================81th iteration=========================
# ==========================82th iteration=========================
# ==========================83th iteration=========================
# ==========================84th iteration=========================
# ==========================85th iteration=========================
# ==========================86th iteration=========================
# ==========================87th iteration=========================
# ==========================88th iteration=========================
# ==========================89th iteration=========================
# ==========================90th iteration=========================
# ==========================91th iteration=========================
# ==========================92th iteration=========================
# ==========================93th iteration=========================
# ==========================94th iteration=========================
# ==========================95th iteration=========================
# ==========================96th iteration=========================
# ==========================97th iteration=========================
# ==========================98th iteration=========================
# ==========================99th iteration=========================
# ==========================100th iteration=========================
# ==========================101th iteration=========================
# ==========================102th iteration=========================
# ==========================103th iteration=========================
# ==========================104th iteration=========================
# ==========================105th iteration=========================
# ==========================106th iteration=========================
# ==========================107th iteration=========================
# ==========================108th iteration=========================
# ==========================109th iteration=========================
# ==========================110th iteration=========================
# ==========================111th iteration=========================
# ==========================112th iteration=========================
# ==========================113th iteration=========================
# ==========================114th iteration=========================
# ==========================115th iteration=========================
# ==========================116th iteration=========================
# ==========================117th iteration=========================
# ==========================118th iteration=========================
# ==========================119th iteration=========================
# ==========================120th iteration=========================
# ==========================121th iteration=========================
# ==========================122th iteration=========================
# ==========================123th iteration=========================
# ==========================124th iteration=========================
# ==========================125th iteration=========================
# ==========================126th iteration=========================
# ==========================127th iteration=========================
# ==========================128th iteration=========================
# ==========================129th iteration=========================
# ==========================130th iteration=========================
# ==========================131th iteration=========================
# ==========================132th iteration=========================
# ==========================133th iteration=========================
# ==========================134th iteration=========================
# ==========================135th iteration=========================
# ==========================136th iteration=========================
# ==========================137th iteration=========================
# ==========================138th iteration=========================
# ==========================139th iteration=========================
# ==========================140th iteration=========================
# ==========================141th iteration=========================
# ==========================142th iteration=========================
# ==========================143th iteration=========================
# ==========================144th iteration=========================
# ==========================145th iteration=========================
# ==========================146th iteration=========================
# ==========================147th iteration=========================
# ==========================148th iteration=========================
# ==========================149th iteration=========================
# ==========================150th iteration=========================
# ==========================151th iteration=========================
# ==========================152th iteration=========================
# ==========================153th iteration=========================
# ==========================154th iteration=========================
# ==========================155th iteration=========================
# ==========================156th iteration=========================
# ==========================157th iteration=========================
# ==========================158th iteration=========================
# ==========================159th iteration=========================
# ==========================160th iteration=========================
# ==========================161th iteration=========================
# ==========================162th iteration=========================
# ==========================163th iteration=========================
# ==========================164th iteration=========================
# ==========================165th iteration=========================
# ==========================166th iteration=========================
# ==========================167th iteration=========================
# ==========================168th iteration=========================
# ==========================169th iteration=========================
# ==========================170th iteration=========================
# ==========================171th iteration=========================
# ==========================172th iteration=========================
# ==========================173th iteration=========================
# ==========================174th iteration=========================
# ==========================175th iteration=========================
# ==========================176th iteration=========================
# ==========================177th iteration=========================
# ==========================178th iteration=========================
# ==========================179th iteration=========================
# ==========================180th iteration=========================
# ==========================181th iteration=========================
# ==========================182th iteration=========================
# ==========================183th iteration=========================
# ==========================184th iteration=========================
# ==========================185th iteration=========================
# ==========================186th iteration=========================
# ==========================187th iteration=========================
# ==========================188th iteration=========================
# ==========================189th iteration=========================
# ==========================190th iteration=========================
# ==========================191th iteration=========================
# ==========================192th iteration=========================
# ==========================193th iteration=========================
# ==========================194th iteration=========================
# ==========================195th iteration=========================
# ==========================196th iteration=========================
# ==========================197th iteration=========================
# ==========================198th iteration=========================
# ==========================199th iteration=========================
# ==========================200th iteration=========================
# ==========================201th iteration=========================
# ==========================202th iteration=========================
# ==========================203th iteration=========================
# ==========================204th iteration=========================
# ==========================205th iteration=========================
# ==========================206th iteration=========================
# ==========================207th iteration=========================
# ==========================208th iteration=========================
# ==========================209th iteration=========================
# ==========================210th iteration=========================
# ==========================211th iteration=========================
# ==========================212th iteration=========================
# ==========================213th iteration=========================
# ==========================214th iteration=========================
# ==========================215th iteration=========================
# ==========================216th iteration=========================
# ==========================217th iteration=========================
# ==========================218th iteration=========================
# ==========================219th iteration=========================
# ==========================220th iteration=========================
# ==========================221th iteration=========================
# ==========================222th iteration=========================
# ==========================223th iteration=========================
# ==========================224th iteration=========================
# ==========================225th iteration=========================
# ==========================226th iteration=========================
# ==========================227th iteration=========================
# ==========================228th iteration=========================
# ==========================229th iteration=========================
# ==========================230th iteration=========================
# ==========================231th iteration=========================
# ==========================232th iteration=========================
# ==========================233th iteration=========================
# ==========================234th iteration=========================
# ==========================235th iteration=========================
# ==========================236th iteration=========================
# ==========================237th iteration=========================
# ==========================238th iteration=========================
# ==========================239th iteration=========================
# ==========================240th iteration=========================
# ==========================241th iteration=========================
# ==========================242th iteration=========================
# ==========================243th iteration=========================
# ==========================244th iteration=========================
# ==========================245th iteration=========================
# ==========================246th iteration=========================
# ==========================247th iteration=========================
# ==========================248th iteration=========================
# ==========================249th iteration=========================
# ==========================250th iteration=========================
# ==========================251th iteration=========================
# ==========================252th iteration=========================
# ==========================253th iteration=========================
# ==========================254th iteration=========================
# ==========================255th iteration=========================
# ==========================256th iteration=========================
# ==========================257th iteration=========================
# ==========================258th iteration=========================
# ==========================259th iteration=========================
# ==========================260th iteration=========================
# ==========================261th iteration=========================
# ==========================262th iteration=========================
# ==========================263th iteration=========================
# ==========================264th iteration=========================
# ==========================265th iteration=========================
# ==========================266th iteration=========================
# ==========================267th iteration=========================
# ==========================268th iteration=========================
# ==========================269th iteration=========================
# ==========================270th iteration=========================
# ==========================271th iteration=========================
# ==========================272th iteration=========================
# ==========================273th iteration=========================
# ==========================274th iteration=========================
# ==========================275th iteration=========================
# ==========================276th iteration=========================
# ==========================277th iteration=========================
# ==========================278th iteration=========================
# ==========================279th iteration=========================
# ==========================280th iteration=========================
# ==========================281th iteration=========================
# ==========================282th iteration=========================
# ==========================283th iteration=========================
# ==========================284th iteration=========================
# ==========================285th iteration=========================
# ==========================286th iteration=========================
# ==========================287th iteration=========================
# ==========================288th iteration=========================
# ==========================289th iteration=========================
# ==========================290th iteration=========================
# ==========================291th iteration=========================
# ==========================292th iteration=========================
# ==========================293th iteration=========================
# ==========================294th iteration=========================
# ==========================295th iteration=========================
# ==========================296th iteration=========================
# ==========================297th iteration=========================
# ==========================298th iteration=========================
# ==========================299th iteration=========================
# ==========================300th iteration=========================
# ==========================301th iteration=========================
# ==========================302th iteration=========================
# ==========================303th iteration=========================
# ==========================304th iteration=========================
# ==========================305th iteration=========================
# ==========================306th iteration=========================
# ==========================307th iteration=========================
# ==========================308th iteration=========================
# ==========================309th iteration=========================
# ==========================310th iteration=========================
# ==========================311th iteration=========================
# ==========================312th iteration=========================
# ==========================313th iteration=========================
# ==========================314th iteration=========================
# ==========================315th iteration=========================
# ==========================316th iteration=========================
# ==========================317th iteration=========================
# ==========================318th iteration=========================
# ==========================319th iteration=========================
# ==========================320th iteration=========================
# ==========================321th iteration=========================
# ==========================322th iteration=========================
# ==========================323th iteration=========================
# ==========================324th iteration=========================
# ==========================325th iteration=========================
# ==========================326th iteration=========================
# ==========================327th iteration=========================
# ==========================328th iteration=========================
# ==========================329th iteration=========================
# ==========================330th iteration=========================
# ==========================331th iteration=========================
# ==========================332th iteration=========================
# ==========================333th iteration=========================
# ==========================334th iteration=========================
# ==========================335th iteration=========================
# ==========================336th iteration=========================
# ==========================337th iteration=========================
# ==========================338th iteration=========================
# ==========================339th iteration=========================
# ==========================340th iteration=========================
# ==========================341th iteration=========================
# ==========================342th iteration=========================
# ==========================343th iteration=========================
# ==========================344th iteration=========================
# ==========================345th iteration=========================
# ==========================346th iteration=========================
# ==========================347th iteration=========================
# ==========================348th iteration=========================
# ==========================349th iteration=========================
# ==========================350th iteration=========================
# ==========================351th iteration=========================
# ==========================352th iteration=========================
# ==========================353th iteration=========================
# ==========================354th iteration=========================
# ==========================355th iteration=========================
# ==========================356th iteration=========================
# ==========================357th iteration=========================
# ==========================358th iteration=========================
# ==========================359th iteration=========================
# ==========================360th iteration=========================
# ==========================361th iteration=========================
# ==========================362th iteration=========================
# ==========================363th iteration=========================
# ==========================364th iteration=========================
# ==========================365th iteration=========================
# ==========================366th iteration=========================
# ==========================367th iteration=========================
# ==========================368th iteration=========================
# ==========================369th iteration=========================
# ==========================370th iteration=========================
# ==========================371th iteration=========================
# ==========================372th iteration=========================
# ==========================373th iteration=========================
# ==========================374th iteration=========================
# ==========================375th iteration=========================
# ==========================376th iteration=========================
# ==========================377th iteration=========================
# ==========================378th iteration=========================
# ==========================379th iteration=========================
# ==========================380th iteration=========================
# ==========================381th iteration=========================
# ==========================382th iteration=========================
# ==========================383th iteration=========================
# ==========================384th iteration=========================
# ==========================385th iteration=========================
# ==========================386th iteration=========================
# ==========================387th iteration=========================
# ==========================388th iteration=========================
# ==========================389th iteration=========================
# ==========================390th iteration=========================
# ==========================391th iteration=========================
# ==========================392th iteration=========================
# ==========================393th iteration=========================
# ==========================394th iteration=========================
# ==========================395th iteration=========================
# ==========================396th iteration=========================
# ==========================397th iteration=========================
# ==========================398th iteration=========================
# ==========================399th iteration=========================
# ==========================400th iteration=========================
# ==========================401th iteration=========================
# ==========================402th iteration=========================
# ==========================403th iteration=========================
# ==========================404th iteration=========================
# ==========================405th iteration=========================
# ==========================406th iteration=========================
# ==========================407th iteration=========================
# ==========================408th iteration=========================
# ==========================409th iteration=========================
# ==========================410th iteration=========================
# ==========================411th iteration=========================
# ==========================412th iteration=========================
# ==========================413th iteration=========================
# ==========================414th iteration=========================
# ==========================415th iteration=========================
# ==========================416th iteration=========================
# ==========================417th iteration=========================
# ==========================418th iteration=========================
# ==========================419th iteration=========================
# ==========================420th iteration=========================
# ==========================421th iteration=========================
# ==========================422th iteration=========================
# ==========================423th iteration=========================
# ==========================424th iteration=========================
# ==========================425th iteration=========================
# ==========================426th iteration=========================
# ==========================427th iteration=========================
# ==========================428th iteration=========================
# ==========================429th iteration=========================
# ==========================430th iteration=========================
# ==========================431th iteration=========================
# ==========================432th iteration=========================
# ==========================433th iteration=========================
# ==========================434th iteration=========================
# ==========================435th iteration=========================
# ==========================436th iteration=========================
# ==========================437th iteration=========================
# ==========================438th iteration=========================
# ==========================439th iteration=========================
# ==========================440th iteration=========================
# ==========================441th iteration=========================
# ==========================442th iteration=========================
# ==========================443th iteration=========================
# ==========================444th iteration=========================
# ==========================445th iteration=========================
# ==========================446th iteration=========================
# ==========================447th iteration=========================
# ==========================448th iteration=========================
# ==========================449th iteration=========================
# ==========================450th iteration=========================
# ==========================451th iteration=========================
# ==========================452th iteration=========================
# ==========================453th iteration=========================
# ==========================454th iteration=========================
# ==========================455th iteration=========================
# ==========================456th iteration=========================
# ==========================457th iteration=========================
# ==========================458th iteration=========================
# ==========================459th iteration=========================
# ==========================460th iteration=========================
# ==========================461th iteration=========================
# ==========================462th iteration=========================
# ==========================463th iteration=========================
# ==========================464th iteration=========================
# ==========================465th iteration=========================
# ==========================466th iteration=========================
# ==========================467th iteration=========================
# ==========================468th iteration=========================
# ==========================469th iteration=========================
# ==========================470th iteration=========================
# ==========================471th iteration=========================
# ==========================472th iteration=========================
# ==========================473th iteration=========================
# ==========================474th iteration=========================
# ==========================475th iteration=========================
# ==========================476th iteration=========================
# ==========================477th iteration=========================
# ==========================478th iteration=========================
# ==========================479th iteration=========================
# ==========================480th iteration=========================
# ==========================481th iteration=========================
# ==========================482th iteration=========================
# ==========================483th iteration=========================
# ==========================484th iteration=========================
# ==========================485th iteration=========================
# ==========================486th iteration=========================
# ==========================487th iteration=========================
# ==========================488th iteration=========================
# ==========================489th iteration=========================
# ==========================490th iteration=========================
# ==========================491th iteration=========================
# ==========================492th iteration=========================
# ==========================493th iteration=========================
# ==========================494th iteration=========================
# ==========================495th iteration=========================
# ==========================496th iteration=========================
# ==========================497th iteration=========================
# ==========================498th iteration=========================
# ==========================499th iteration=========================
# ==========================500th iteration=========================
# ==========================501th iteration=========================
# ==========================502th iteration=========================
# ==========================503th iteration=========================
# ==========================504th iteration=========================
# ==========================505th iteration=========================
# ==========================506th iteration=========================
# ==========================507th iteration=========================
# ==========================508th iteration=========================
# ==========================509th iteration=========================
# ==========================510th iteration=========================
# ==========================511th iteration=========================
# ==========================512th iteration=========================
# ==========================513th iteration=========================
# ==========================514th iteration=========================
# ==========================515th iteration=========================
# ==========================516th iteration=========================
# ==========================517th iteration=========================
# ==========================518th iteration=========================
# ==========================519th iteration=========================
# ==========================520th iteration=========================
# ==========================521th iteration=========================
# ==========================522th iteration=========================
# ==========================523th iteration=========================
# ==========================524th iteration=========================
# ==========================525th iteration=========================
# ==========================526th iteration=========================
# ==========================527th iteration=========================
# ==========================528th iteration=========================
# ==========================529th iteration=========================
# ==========================530th iteration=========================
# ==========================531th iteration=========================
# ==========================532th iteration=========================
# ==========================533th iteration=========================
# ==========================534th iteration=========================
# ==========================535th iteration=========================
# ==========================536th iteration=========================
# ==========================537th iteration=========================
# ==========================538th iteration=========================
# ==========================539th iteration=========================
# ==========================540th iteration=========================
# ==========================541th iteration=========================
# ==========================542th iteration=========================
# ==========================543th iteration=========================
# ==========================544th iteration=========================
# ==========================545th iteration=========================
# ==========================546th iteration=========================
# ==========================547th iteration=========================
# ==========================548th iteration=========================
# ==========================549th iteration=========================
# ==========================550th iteration=========================
# ==========================551th iteration=========================
# ==========================552th iteration=========================
# ==========================553th iteration=========================
# ==========================554th iteration=========================
# ==========================555th iteration=========================
# ==========================556th iteration=========================
# ==========================557th iteration=========================
# ==========================558th iteration=========================
# ==========================559th iteration=========================
# ==========================560th iteration=========================
# ==========================561th iteration=========================
# ==========================562th iteration=========================
# ==========================563th iteration=========================
# ==========================564th iteration=========================
# ==========================565th iteration=========================
# ==========================566th iteration=========================
# ==========================567th iteration=========================
# ==========================568th iteration=========================
# ==========================569th iteration=========================
# ==========================570th iteration=========================
# ==========================571th iteration=========================
# ==========================572th iteration=========================
# ==========================573th iteration=========================
# ==========================574th iteration=========================
# ==========================575th iteration=========================
# ==========================576th iteration=========================
# ==========================577th iteration=========================
# ==========================578th iteration=========================
# ==========================579th iteration=========================
# ==========================580th iteration=========================
# ==========================581th iteration=========================
# ==========================582th iteration=========================
# ==========================583th iteration=========================
# ==========================584th iteration=========================
# ==========================585th iteration=========================
# ==========================586th iteration=========================
# ==========================587th iteration=========================
# ==========================588th iteration=========================
# ==========================589th iteration=========================
# ==========================590th iteration=========================
# ==========================591th iteration=========================
# ==========================592th iteration=========================
# ==========================593th iteration=========================
# ==========================594th iteration=========================
# ==========================595th iteration=========================
# ==========================596th iteration=========================
# ==========================597th iteration=========================
# ==========================598th iteration=========================
# ==========================599th iteration=========================
# ==========================600th iteration=========================
# ==========================601th iteration=========================
# ==========================602th iteration=========================
# ==========================603th iteration=========================
# ==========================604th iteration=========================
# ==========================605th iteration=========================
# ==========================606th iteration=========================
# ==========================607th iteration=========================
# ==========================608th iteration=========================
# ==========================609th iteration=========================
# ==========================610th iteration=========================
# ==========================611th iteration=========================
# ==========================612th iteration=========================
# ==========================613th iteration=========================
# ==========================614th iteration=========================
# ==========================615th iteration=========================
# ==========================616th iteration=========================
# ==========================617th iteration=========================
# ==========================618th iteration=========================
# ==========================619th iteration=========================
# ==========================620th iteration=========================
# ==========================621th iteration=========================
# ==========================622th iteration=========================
# ==========================623th iteration=========================
# ==========================624th iteration=========================
# ==========================625th iteration=========================
# ==========================626th iteration=========================
# ==========================627th iteration=========================
# ==========================628th iteration=========================
# ==========================629th iteration=========================
# ==========================630th iteration=========================
# ==========================631th iteration=========================
# ==========================632th iteration=========================
# ==========================633th iteration=========================
# ==========================634th iteration=========================
# ==========================635th iteration=========================
# ==========================636th iteration=========================
# ==========================637th iteration=========================
# ==========================638th iteration=========================
# ==========================639th iteration=========================
# ==========================640th iteration=========================
# ==========================641th iteration=========================
# ==========================642th iteration=========================
# ==========================643th iteration=========================
# ==========================644th iteration=========================
# ==========================645th iteration=========================
# ==========================646th iteration=========================
# ==========================647th iteration=========================
# ==========================648th iteration=========================
# ==========================649th iteration=========================
# ==========================650th iteration=========================
# ==========================651th iteration=========================
# ==========================652th iteration=========================
# ==========================653th iteration=========================
# ==========================654th iteration=========================
# ==========================655th iteration=========================
# ==========================656th iteration=========================
# ==========================657th iteration=========================
# ==========================658th iteration=========================
# ==========================659th iteration=========================
# ==========================660th iteration=========================
# ==========================661th iteration=========================
# ==========================662th iteration=========================
# ==========================663th iteration=========================
# ==========================664th iteration=========================
# ==========================665th iteration=========================
# ==========================666th iteration=========================
# ==========================667th iteration=========================
# ==========================668th iteration=========================
# ==========================669th iteration=========================
# ==========================670th iteration=========================
# ==========================671th iteration=========================
# ==========================672th iteration=========================
# ==========================673th iteration=========================
# ==========================674th iteration=========================
# ==========================675th iteration=========================
# ==========================676th iteration=========================
# ==========================677th iteration=========================
# ==========================678th iteration=========================
# ==========================679th iteration=========================
# ==========================680th iteration=========================
# ==========================681th iteration=========================
# ==========================682th iteration=========================
# ==========================683th iteration=========================
# ==========================684th iteration=========================
# ==========================685th iteration=========================
# ==========================686th iteration=========================
# ==========================687th iteration=========================
# ==========================688th iteration=========================
# ==========================689th iteration=========================
# ==========================690th iteration=========================
# ==========================691th iteration=========================
# ==========================692th iteration=========================
# ==========================693th iteration=========================
# ==========================694th iteration=========================
# ==========================695th iteration=========================
# ==========================696th iteration=========================
# ==========================697th iteration=========================
# ==========================698th iteration=========================
# ==========================699th iteration=========================
# ==========================700th iteration=========================
# ==========================701th iteration=========================
# ==========================702th iteration=========================
# ==========================703th iteration=========================
# ==========================704th iteration=========================
# ==========================705th iteration=========================
# ==========================706th iteration=========================
# ==========================707th iteration=========================
# ==========================708th iteration=========================
# ==========================709th iteration=========================
# ==========================710th iteration=========================
# ==========================711th iteration=========================
# ==========================712th iteration=========================
# ==========================713th iteration=========================
# ==========================714th iteration=========================
# ==========================715th iteration=========================
# ==========================716th iteration=========================
# ==========================717th iteration=========================
# ==========================718th iteration=========================
# ...
# ==========================28013th iteration=========================
# ==========================28014th iteration=========================
# ==========================28015th iteration=========================
# ==========================28016th iteration=========================
# ==========================28017th iteration=========================
# ==========================28018th iteration=========================
# ==========================28019th iteration=========================
# ==========================28020th iteration=========================
# ==========================28021th iteration=========================
# ==========================28022th iteration=========================
# ==========================28023th iteration=========================
# ==========================28024th iteration=========================
# ==========================28025th iteration=========================
# ==========================28026th iteration=========================
# ==========================28027th iteration=========================
# ==========================28028th iteration=========================
# ==========================28029th iteration=========================
# ==========================28030th iteration=========================
# ==========================28031th iteration=========================
# ==========================28032th iteration=========================
# ==========================28033th iteration=========================
# ==========================28034th iteration=========================
# ==========================28035th iteration=========================
# ==========================28036th iteration=========================
# ==========================28037th iteration=========================
# ==========================28038th iteration=========================
# ==========================28039th iteration=========================
# ==========================28040th iteration=========================
# ==========================28041th iteration=========================
# ==========================28042th iteration=========================
# ==========================28043th iteration=========================
# ==========================28044th iteration=========================
# ==========================28045th iteration=========================
# ==========================28046th iteration=========================
# ==========================28047th iteration=========================
# ==========================28048th iteration=========================
# ==========================28049th iteration=========================
# ==========================28050th iteration=========================
# ==========================28051th iteration=========================
# ==========================28052th iteration=========================
# ==========================28053th iteration=========================
# ==========================28054th iteration=========================
# ==========================28055th iteration=========================
# ==========================28056th iteration=========================
# ==========================28057th iteration=========================
# ==========================28058th iteration=========================
# ==========================28059th iteration=========================
# ==========================28060th iteration=========================
# ==========================28061th iteration=========================
# ==========================28062th iteration=========================
# ==========================28063th iteration=========================
# ==========================28064th iteration=========================
# ==========================28065th iteration=========================
# ==========================28066th iteration=========================
# ==========================28067th iteration=========================
# ==========================28068th iteration=========================
# ==========================28069th iteration=========================
# ==========================28070th iteration=========================
# ==========================28071th iteration=========================
# ==========================28072th iteration=========================
# ==========================28073th iteration=========================
# ==========================28074th iteration=========================
# ==========================28075th iteration=========================
# ==========================28076th iteration=========================
# ==========================28077th iteration=========================
# ==========================28078th iteration=========================
# ==========================28079th iteration=========================
# ==========================28080th iteration=========================
# ==========================28081th iteration=========================
# ==========================28082th iteration=========================
# ==========================28083th iteration=========================
# ==========================28084th iteration=========================
# ==========================28085th iteration=========================
# ==========================28086th iteration=========================
# ==========================28087th iteration=========================
# ==========================28088th iteration=========================
# ==========================28089th iteration=========================
# ==========================28090th iteration=========================
# ==========================28091th iteration=========================
# ==========================28092th iteration=========================
# ==========================28093th iteration=========================
# ==========================28094th iteration=========================
# ==========================28095th iteration=========================
# ==========================28096th iteration=========================
# ==========================28097th iteration=========================
# ==========================28098th iteration=========================
# ==========================28099th iteration=========================
# ==========================28100th iteration=========================
# ==========================28101th iteration=========================
# ==========================28102th iteration=========================
# ==========================28103th iteration=========================
# ==========================28104th iteration=========================
# ==========================28105th iteration=========================
# ==========================28106th iteration=========================
# ==========================28107th iteration=========================
# ==========================28108th iteration=========================
# ==========================28109th iteration=========================
# ==========================28110th iteration=========================
# ==========================28111th iteration=========================
# ==========================28112th iteration=========================
# ==========================28113th iteration=========================
# ==========================28114th iteration=========================
# ==========================28115th iteration=========================
# ==========================28116th iteration=========================
# ==========================28117th iteration=========================
# ==========================28118th iteration=========================
# ==========================28119th iteration=========================
# ==========================28120th iteration=========================
# ==========================28121th iteration=========================
# ==========================28122th iteration=========================
# ==========================28123th iteration=========================
# ==========================28124th iteration=========================
# ==========================28125th iteration=========================
# ==========================28126th iteration=========================
# ==========================28127th iteration=========================
# ==========================28128th iteration=========================
# ==========================28129th iteration=========================
# ==========================28130th iteration=========================
# ==========================28131th iteration=========================
# ==========================28132th iteration=========================
# ==========================28133th iteration=========================
# ==========================28134th iteration=========================
# ==========================28135th iteration=========================
# ==========================28136th iteration=========================
# ==========================28137th iteration=========================
# ==========================28138th iteration=========================
# ==========================28139th iteration=========================
# ==========================28140th iteration=========================
# ==========================28141th iteration=========================
# ==========================28142th iteration=========================
# ==========================28143th iteration=========================
# ==========================28144th iteration=========================
# ==========================28145th iteration=========================
# ==========================28146th iteration=========================
# ==========================28147th iteration=========================
# ==========================28148th iteration=========================
# ==========================28149th iteration=========================
# ==========================28150th iteration=========================
# ==========================28151th iteration=========================
# ==========================28152th iteration=========================
# ==========================28153th iteration=========================
# ==========================28154th iteration=========================
# ==========================28155th iteration=========================
# ==========================28156th iteration=========================
# ==========================28157th iteration=========================
# ==========================28158th iteration=========================
# ==========================28159th iteration=========================
# ==========================28160th iteration=========================
# ==========================28161th iteration=========================
# ==========================28162th iteration=========================
# ==========================28163th iteration=========================
# ==========================28164th iteration=========================
# ==========================28165th iteration=========================
# ==========================28166th iteration=========================
# ==========================28167th iteration=========================
# ==========================28168th iteration=========================
# ==========================28169th iteration=========================
# ==========================28170th iteration=========================
# ==========================28171th iteration=========================
# ==========================28172th iteration=========================
# ==========================28173th iteration=========================
# ==========================28174th iteration=========================
# ==========================28175th iteration=========================
# ==========================28176th iteration=========================
# ==========================28177th iteration=========================
# ==========================28178th iteration=========================
# ==========================28179th iteration=========================
# ==========================28180th iteration=========================
# ==========================28181th iteration=========================
# ==========================28182th iteration=========================
# ==========================28183th iteration=========================
# ==========================28184th iteration=========================
# ==========================28185th iteration=========================
# ==========================28186th iteration=========================
# ==========================28187th iteration=========================
# ==========================28188th iteration=========================
# ==========================28189th iteration=========================
# ==========================28190th iteration=========================
# ==========================28191th iteration=========================
# ==========================28192th iteration=========================
# ==========================28193th iteration=========================
# ==========================28194th iteration=========================
# ==========================28195th iteration=========================
# ==========================28196th iteration=========================
# ==========================28197th iteration=========================
# ==========================28198th iteration=========================
# ==========================28199th iteration=========================
# ==========================28200th iteration=========================
# ==========================28201th iteration=========================
# ==========================28202th iteration=========================
# ==========================28203th iteration=========================
# ==========================28204th iteration=========================
# ==========================28205th iteration=========================
# ==========================28206th iteration=========================
# ==========================28207th iteration=========================
# ==========================28208th iteration=========================
# ==========================28209th iteration=========================
# ==========================28210th iteration=========================
# ==========================28211th iteration=========================
# ==========================28212th iteration=========================
# ==========================28213th iteration=========================
# ==========================28214th iteration=========================
# ==========================28215th iteration=========================
# ==========================28216th iteration=========================
# ==========================28217th iteration=========================
# ==========================28218th iteration=========================
# ==========================28219th iteration=========================
# ==========================28220th iteration=========================
# ==========================28221th iteration=========================
# ==========================28222th iteration=========================
# ==========================28223th iteration=========================
# ==========================28224th iteration=========================
# ==========================28225th iteration=========================
# ==========================28226th iteration=========================
# ==========================28227th iteration=========================
# ==========================28228th iteration=========================
# ==========================28229th iteration=========================
# ==========================28230th iteration=========================
# ==========================28231th iteration=========================
# ==========================28232th iteration=========================
# ==========================28233th iteration=========================
# ==========================28234th iteration=========================
# ==========================28235th iteration=========================
# ==========================28236th iteration=========================
# ==========================28237th iteration=========================
# ==========================28238th iteration=========================
# ==========================28239th iteration=========================
# ==========================28240th iteration=========================
# ==========================28241th iteration=========================
# ==========================28242th iteration=========================
# ==========================28243th iteration=========================

# %% [markdown]
# ## Saving Embedding Matrix for Future use

# %%
# import pickle as pkl
# with open("EmbeddingMatrixBERT.pkl",'wb') as f:
#     pkl.dump([embedding_dim,embedding_matrix],f)

# %% [markdown]
# ## Loding Embedding Matrix

# %%
import pickle as pkl
with open("EmbeddingMatrixBERT.pkl",'rb') as f:
    embedding_dim,embedding_matrix = pkl.load(f)

# %%
embedding_layer = Embedding(len(word_index) + 1,
                            embedding_dim,
                            weights=[embedding_matrix],
                            input_length=max_length,
                            trainable=False)

# %% [markdown]
# ## Creating a CheckPoint

# %%
checkpoint = ModelCheckpoint(filepath="Sarcasm_Bert_Lstm_MBSA_v2.h5", 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')

# %% [markdown]
# # Creating the main Neural Network with LSTM

# %%
model = Sequential()
model.add(embedding_layer)
model.add(LSTM(300,return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(100))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

print('Summary of the built model...')
print(model.summary())
# Out:
# Summary of the built model...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 30, 768)           22009344
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 30, 300)           1282800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 300)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 100)               160400
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 23,452,645
# Trainable params: 1,443,301
# Non-trainable params: 22,009,344
# _________________________________________________________________
# None

# %% [markdown]
# ## Evaluating Model

# %%
history = model.fit(X_train_pad, y_train,epochs=100,callbacks=[checkpoint], validation_data=(X_test_pad, y_test))
# Out:
# Epoch 1/100
# 1384/1384 [==============================] - 22s 15ms/step - loss: 0.6736 - accuracy: 0.5824 - val_loss: 0.6668 - val_accuracy: 0.5827
#
# Epoch 00001: val_loss improved from inf to 0.66679, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 2/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.6584 - accuracy: 0.6041 - val_loss: 0.6430 - val_accuracy: 0.6296
#
# Epoch 00002: val_loss improved from 0.66679 to 0.64296, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 3/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.6327 - accuracy: 0.6400 - val_loss: 0.6154 - val_accuracy: 0.6592
#
# Epoch 00003: val_loss improved from 0.64296 to 0.61545, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 4/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.6103 - accuracy: 0.6675 - val_loss: 0.5995 - val_accuracy: 0.6759
#
# Epoch 00004: val_loss improved from 0.61545 to 0.59951, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 5/100
# 1384/1384 [==============================] - 20s 14ms/step - loss: 0.5915 - accuracy: 0.6859 - val_loss: 0.5856 - val_accuracy: 0.6930
#
# Epoch 00005: val_loss improved from 0.59951 to 0.58558, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 6/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.5758 - accuracy: 0.7005 - val_loss: 0.5708 - val_accuracy: 0.7041
#
# Epoch 00006: val_loss improved from 0.58558 to 0.57080, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 7/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.5585 - accuracy: 0.7109 - val_loss: 0.5457 - val_accuracy: 0.7279
#
# Epoch 00007: val_loss improved from 0.57080 to 0.54570, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 8/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.5521 - accuracy: 0.7154 - val_loss: 0.5542 - val_accuracy: 0.7062
#
# Epoch 00008: val_loss did not improve from 0.54570
# Epoch 9/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.5436 - accuracy: 0.7250 - val_loss: 0.5361 - val_accuracy: 0.7327
#
# Epoch 00009: val_loss improved from 0.54570 to 0.53606, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 10/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.5391 - accuracy: 0.7243 - val_loss: 0.5221 - val_accuracy: 0.7408
#
# Epoch 00010: val_loss improved from 0.53606 to 0.52215, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 11/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.5317 - accuracy: 0.7312 - val_loss: 0.5848 - val_accuracy: 0.6788
#
# Epoch 00011: val_loss did not improve from 0.52215
# Epoch 12/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.5234 - accuracy: 0.7371 - val_loss: 0.5252 - val_accuracy: 0.7385
#
# Epoch 00012: val_loss did not improve from 0.52215
# Epoch 13/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.5130 - accuracy: 0.7466 - val_loss: 0.5000 - val_accuracy: 0.7551
#
# Epoch 00013: val_loss improved from 0.52215 to 0.50001, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 14/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.5132 - accuracy: 0.7468 - val_loss: 0.5045 - val_accuracy: 0.7587
#
# Epoch 00014: val_loss did not improve from 0.50001
# Epoch 15/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.5061 - accuracy: 0.7508 - val_loss: 0.5089 - val_accuracy: 0.7530
#
# Epoch 00015: val_loss did not improve from 0.50001
# Epoch 16/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4993 - accuracy: 0.7567 - val_loss: 0.4907 - val_accuracy: 0.7648
#
# Epoch 00016: val_loss improved from 0.50001 to 0.49071, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 17/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4921 - accuracy: 0.7600 - val_loss: 0.4878 - val_accuracy: 0.7632
#
# Epoch 00017: val_loss improved from 0.49071 to 0.48780, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 18/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.4889 - accuracy: 0.7626 - val_loss: 0.4799 - val_accuracy: 0.7680
#
# Epoch 00018: val_loss improved from 0.48780 to 0.47987, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 19/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4827 - accuracy: 0.7658 - val_loss: 0.5184 - val_accuracy: 0.7484
#
# Epoch 00019: val_loss did not improve from 0.47987
# Epoch 20/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4791 - accuracy: 0.7672 - val_loss: 0.4953 - val_accuracy: 0.7556
#
# Epoch 00020: val_loss did not improve from 0.47987
# Epoch 21/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.4780 - accuracy: 0.7672 - val_loss: 0.4747 - val_accuracy: 0.7722
#
# Epoch 00021: val_loss improved from 0.47987 to 0.47467, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 22/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.4712 - accuracy: 0.7745 - val_loss: 0.4907 - val_accuracy: 0.7657
#
# Epoch 00022: val_loss did not improve from 0.47467
# Epoch 23/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4690 - accuracy: 0.7751 - val_loss: 0.4695 - val_accuracy: 0.7743
#
# Epoch 00023: val_loss improved from 0.47467 to 0.46953, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 24/100
# 1384/1384 [==============================] - 20s 14ms/step - loss: 0.4629 - accuracy: 0.7799 - val_loss: 0.4746 - val_accuracy: 0.7704
#
# Epoch 00024: val_loss did not improve from 0.46953
# Epoch 25/100
# 1384/1384 [==============================] - 20s 14ms/step - loss: 0.4602 - accuracy: 0.7796 - val_loss: 0.4609 - val_accuracy: 0.7826
#
# Epoch 00025: val_loss improved from 0.46953 to 0.46086, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 26/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4529 - accuracy: 0.7840 - val_loss: 0.4677 - val_accuracy: 0.7714
#
# Epoch 00026: val_loss did not improve from 0.46086
# Epoch 27/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4499 - accuracy: 0.7844 - val_loss: 0.4781 - val_accuracy: 0.7695
#
# Epoch 00027: val_loss did not improve from 0.46086
# Epoch 28/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4471 - accuracy: 0.7869 - val_loss: 0.4531 - val_accuracy: 0.7854
#
# Epoch 00028: val_loss improved from 0.46086 to 0.45312, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 29/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4440 - accuracy: 0.7893 - val_loss: 0.5083 - val_accuracy: 0.7435
#
# Epoch 00029: val_loss did not improve from 0.45312
# Epoch 30/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4416 - accuracy: 0.7898 - val_loss: 0.4795 - val_accuracy: 0.7658
#
# Epoch 00030: val_loss did not improve from 0.45312
# Epoch 31/100
# 1384/1384 [==============================] - 20s 14ms/step - loss: 0.4350 - accuracy: 0.7936 - val_loss: 0.4929 - val_accuracy: 0.7656
#
# Epoch 00031: val_loss did not improve from 0.45312
# Epoch 32/100
# 1384/1384 [==============================] - 20s 14ms/step - loss: 0.4358 - accuracy: 0.7935 - val_loss: 0.4515 - val_accuracy: 0.7850
#
# Epoch 00032: val_loss improved from 0.45312 to 0.45148, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 33/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4268 - accuracy: 0.7971 - val_loss: 0.4530 - val_accuracy: 0.7914
#
# Epoch 00033: val_loss did not improve from 0.45148
# Epoch 34/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4211 - accuracy: 0.8033 - val_loss: 0.4439 - val_accuracy: 0.7904
#
# Epoch 00034: val_loss improved from 0.45148 to 0.44388, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 35/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4176 - accuracy: 0.8025 - val_loss: 0.4428 - val_accuracy: 0.7864
#
# Epoch 00035: val_loss improved from 0.44388 to 0.44277, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 36/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4121 - accuracy: 0.8054 - val_loss: 0.4963 - val_accuracy: 0.7674
#
# Epoch 00036: val_loss did not improve from 0.44277
# Epoch 37/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.4070 - accuracy: 0.8072 - val_loss: 0.5109 - val_accuracy: 0.7555
#
# Epoch 00037: val_loss did not improve from 0.44277
# Epoch 38/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4001 - accuracy: 0.8141 - val_loss: 0.4508 - val_accuracy: 0.7903
#
# Epoch 00038: val_loss did not improve from 0.44277
# Epoch 39/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.4020 - accuracy: 0.8117 - val_loss: 0.4576 - val_accuracy: 0.7871
#
# Epoch 00039: val_loss did not improve from 0.44277
# Epoch 40/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.3913 - accuracy: 0.8183 - val_loss: 0.4706 - val_accuracy: 0.7683
#
# Epoch 00040: val_loss did not improve from 0.44277
# Epoch 41/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.3887 - accuracy: 0.8192 - val_loss: 0.4237 - val_accuracy: 0.8026
#
# Epoch 00041: val_loss improved from 0.44277 to 0.42371, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 42/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.3832 - accuracy: 0.8224 - val_loss: 0.4190 - val_accuracy: 0.8088
#
# Epoch 00042: val_loss improved from 0.42371 to 0.41903, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 43/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.3751 - accuracy: 0.8263 - val_loss: 0.4220 - val_accuracy: 0.8031
#
# Epoch 00043: val_loss did not improve from 0.41903
# Epoch 44/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.3659 - accuracy: 0.8333 - val_loss: 0.4263 - val_accuracy: 0.8057
#
# Epoch 00044: val_loss did not improve from 0.41903
# Epoch 45/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.3574 - accuracy: 0.8354 - val_loss: 0.4130 - val_accuracy: 0.8088
#
# Epoch 00045: val_loss improved from 0.41903 to 0.41298, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 46/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.3557 - accuracy: 0.8383 - val_loss: 0.4215 - val_accuracy: 0.8112
#
# Epoch 00046: val_loss did not improve from 0.41298
# Epoch 47/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.3454 - accuracy: 0.8415 - val_loss: 0.4253 - val_accuracy: 0.8107
#
# Epoch 00047: val_loss did not improve from 0.41298
# Epoch 48/100
# 1384/1384 [==============================] - 20s 14ms/step - loss: 0.3409 - accuracy: 0.8444 - val_loss: 0.4187 - val_accuracy: 0.8106
#
# Epoch 00048: val_loss did not improve from 0.41298
# Epoch 49/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.3314 - accuracy: 0.8491 - val_loss: 0.4332 - val_accuracy: 0.8123
#
# Epoch 00049: val_loss did not improve from 0.41298
# Epoch 50/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.3277 - accuracy: 0.8514 - val_loss: 0.4076 - val_accuracy: 0.8281
#
# Epoch 00050: val_loss improved from 0.41298 to 0.40762, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 51/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.3164 - accuracy: 0.8573 - val_loss: 0.4320 - val_accuracy: 0.8059
#
# Epoch 00051: val_loss did not improve from 0.40762
# Epoch 52/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.3157 - accuracy: 0.8586 - val_loss: 0.4017 - val_accuracy: 0.8179
#
# Epoch 00052: val_loss improved from 0.40762 to 0.40169, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 53/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.3059 - accuracy: 0.8646 - val_loss: 0.4222 - val_accuracy: 0.8155
#
# Epoch 00053: val_loss did not improve from 0.40169
# Epoch 54/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.2963 - accuracy: 0.8689 - val_loss: 0.4009 - val_accuracy: 0.8255
#
# Epoch 00054: val_loss improved from 0.40169 to 0.40086, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 55/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.2873 - accuracy: 0.8730 - val_loss: 0.4061 - val_accuracy: 0.8254
#
# Epoch 00055: val_loss did not improve from 0.40086
# Epoch 56/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.2792 - accuracy: 0.8775 - val_loss: 0.3796 - val_accuracy: 0.8361
#
# Epoch 00056: val_loss improved from 0.40086 to 0.37959, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 57/100
# 1384/1384 [==============================] - 20s 14ms/step - loss: 0.2782 - accuracy: 0.8791 - val_loss: 0.3758 - val_accuracy: 0.8449
#
# Epoch 00057: val_loss improved from 0.37959 to 0.37577, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 58/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.2657 - accuracy: 0.8855 - val_loss: 0.3654 - val_accuracy: 0.8417
#
# Epoch 00058: val_loss improved from 0.37577 to 0.36539, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 59/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.2552 - accuracy: 0.8902 - val_loss: 0.3570 - val_accuracy: 0.8515
#
# Epoch 00059: val_loss improved from 0.36539 to 0.35696, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 60/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.2446 - accuracy: 0.8930 - val_loss: 0.3671 - val_accuracy: 0.8474
#
# Epoch 00060: val_loss did not improve from 0.35696
# Epoch 61/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.2364 - accuracy: 0.8977 - val_loss: 0.3854 - val_accuracy: 0.8388
#
# Epoch 00061: val_loss did not improve from 0.35696
# Epoch 62/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.2273 - accuracy: 0.9040 - val_loss: 0.3786 - val_accuracy: 0.8351
#
# Epoch 00062: val_loss did not improve from 0.35696
# Epoch 63/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.2147 - accuracy: 0.9099 - val_loss: 0.3605 - val_accuracy: 0.8577
#
# Epoch 00063: val_loss did not improve from 0.35696
# Epoch 64/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.2112 - accuracy: 0.9103 - val_loss: 0.3891 - val_accuracy: 0.8463
#
# Epoch 00064: val_loss did not improve from 0.35696
# Epoch 65/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.2069 - accuracy: 0.9129 - val_loss: 0.3652 - val_accuracy: 0.8524
#
# Epoch 00065: val_loss did not improve from 0.35696
# Epoch 66/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.2020 - accuracy: 0.9167 - val_loss: 0.3669 - val_accuracy: 0.8539
#
# Epoch 00066: val_loss did not improve from 0.35696
# Epoch 67/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.1844 - accuracy: 0.9237 - val_loss: 0.3478 - val_accuracy: 0.8698
#
# Epoch 00067: val_loss improved from 0.35696 to 0.34779, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 68/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.1744 - accuracy: 0.9292 - val_loss: 0.3673 - val_accuracy: 0.8614
#
# Epoch 00068: val_loss did not improve from 0.34779
# Epoch 69/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.1673 - accuracy: 0.9330 - val_loss: 0.3435 - val_accuracy: 0.8834
#
# Epoch 00069: val_loss improved from 0.34779 to 0.34351, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 70/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.1537 - accuracy: 0.9394 - val_loss: 0.3456 - val_accuracy: 0.8753
#
# Epoch 00070: val_loss did not improve from 0.34351
# Epoch 71/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.1525 - accuracy: 0.9384 - val_loss: 0.3391 - val_accuracy: 0.8734
#
# Epoch 00071: val_loss improved from 0.34351 to 0.33908, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 72/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.1447 - accuracy: 0.9431 - val_loss: 0.3003 - val_accuracy: 0.8967
#
# Epoch 00072: val_loss improved from 0.33908 to 0.30032, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 73/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.1416 - accuracy: 0.9451 - val_loss: 0.3675 - val_accuracy: 0.8700
#
# Epoch 00073: val_loss did not improve from 0.30032
# Epoch 74/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.1371 - accuracy: 0.9458 - val_loss: 0.4109 - val_accuracy: 0.8602
#
# Epoch 00074: val_loss did not improve from 0.30032
# Epoch 75/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.1295 - accuracy: 0.9497 - val_loss: 0.3869 - val_accuracy: 0.8629
#
# Epoch 00075: val_loss did not improve from 0.30032
# Epoch 76/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.1231 - accuracy: 0.9524 - val_loss: 0.3437 - val_accuracy: 0.8944
#
# Epoch 00076: val_loss did not improve from 0.30032
# Epoch 77/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.1219 - accuracy: 0.9541 - val_loss: 0.2966 - val_accuracy: 0.8999
#
# Epoch 00077: val_loss improved from 0.30032 to 0.29661, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 78/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.1126 - accuracy: 0.9579 - val_loss: 0.3127 - val_accuracy: 0.9007
#
# Epoch 00078: val_loss did not improve from 0.29661
# Epoch 79/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.1117 - accuracy: 0.9578 - val_loss: 0.3392 - val_accuracy: 0.8949
#
# Epoch 00079: val_loss did not improve from 0.29661
# Epoch 80/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.1066 - accuracy: 0.9593 - val_loss: 0.2982 - val_accuracy: 0.9048
#
# Epoch 00080: val_loss did not improve from 0.29661
# Epoch 81/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.1041 - accuracy: 0.9613 - val_loss: 0.3251 - val_accuracy: 0.9003
#
# Epoch 00081: val_loss did not improve from 0.29661
# Epoch 82/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.1030 - accuracy: 0.9618 - val_loss: 0.2991 - val_accuracy: 0.9161
#
# Epoch 00082: val_loss did not improve from 0.29661
# Epoch 83/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.0945 - accuracy: 0.9653 - val_loss: 0.3040 - val_accuracy: 0.9121
#
# Epoch 00083: val_loss did not improve from 0.29661
# Epoch 84/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.0961 - accuracy: 0.9646 - val_loss: 0.2928 - val_accuracy: 0.9100
#
# Epoch 00084: val_loss improved from 0.29661 to 0.29280, saving model to Sarcasm_Bert_Lstm_MBSA_v2.h5
# Epoch 85/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.0872 - accuracy: 0.9689 - val_loss: 0.3004 - val_accuracy: 0.9207
#
# Epoch 00085: val_loss did not improve from 0.29280
# Epoch 86/100
# 1384/1384 [==============================] - 21s 15ms/step - loss: 0.0846 - accuracy: 0.9696 - val_loss: 0.3247 - val_accuracy: 0.9043
#
# Epoch 00086: val_loss did not improve from 0.29280
# Epoch 87/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.0810 - accuracy: 0.9709 - val_loss: 0.4386 - val_accuracy: 0.8783
#
# Epoch 00087: val_loss did not improve from 0.29280
# Epoch 88/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.0831 - accuracy: 0.9703 - val_loss: 0.3094 - val_accuracy: 0.9134
#
# Epoch 00088: val_loss did not improve from 0.29280
# Epoch 89/100
# 1384/1384 [==============================] - 20s 14ms/step - loss: 0.0836 - accuracy: 0.9705 - val_loss: 0.3116 - val_accuracy: 0.9097
#
# Epoch 00089: val_loss did not improve from 0.29280
# Epoch 90/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.0746 - accuracy: 0.9735 - val_loss: 0.3016 - val_accuracy: 0.9194
#
# Epoch 00090: val_loss did not improve from 0.29280
# Epoch 91/100
# 1384/1384 [==============================] - 20s 14ms/step - loss: 0.0755 - accuracy: 0.9729 - val_loss: 0.3717 - val_accuracy: 0.8898
#
# Epoch 00091: val_loss did not improve from 0.29280
# Epoch 92/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.0778 - accuracy: 0.9724 - val_loss: 0.3190 - val_accuracy: 0.9018
#
# Epoch 00092: val_loss did not improve from 0.29280
# Epoch 93/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.0756 - accuracy: 0.9724 - val_loss: 0.3345 - val_accuracy: 0.9075
#
# Epoch 00093: val_loss did not improve from 0.29280
# Epoch 94/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.0672 - accuracy: 0.9760 - val_loss: 0.3026 - val_accuracy: 0.9202
#
# Epoch 00094: val_loss did not improve from 0.29280
# Epoch 95/100
# 1384/1384 [==============================] - 20s 14ms/step - loss: 0.0733 - accuracy: 0.9731 - val_loss: 0.3155 - val_accuracy: 0.9208
#
# Epoch 00095: val_loss did not improve from 0.29280
# Epoch 96/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.0680 - accuracy: 0.9756 - val_loss: 0.3278 - val_accuracy: 0.9140
#
# Epoch 00096: val_loss did not improve from 0.29280
# Epoch 97/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.0622 - accuracy: 0.9781 - val_loss: 0.2946 - val_accuracy: 0.9233
#
# Epoch 00097: val_loss did not improve from 0.29280
# Epoch 98/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.0671 - accuracy: 0.9761 - val_loss: 0.3252 - val_accuracy: 0.9155
#
# Epoch 00098: val_loss did not improve from 0.29280
# Epoch 99/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.0661 - accuracy: 0.9766 - val_loss: 0.3235 - val_accuracy: 0.9147
#
# Epoch 00099: val_loss did not improve from 0.29280
# Epoch 100/100
# 1384/1384 [==============================] - 20s 15ms/step - loss: 0.0607 - accuracy: 0.9796 - val_loss: 0.3347 - val_accuracy: 0.9047
#
# Epoch 00100: val_loss did not improve from 0.29280

# %%
model.evaluate(X_test_pad,y_test)
# Out:
# 346/346 [==============================] - 2s 7ms/step - loss: 0.3347 - accuracy: 0.9047
# [0.33465898036956787, 0.9047446846961975]

# %% [markdown]
# #Saving the model

# %%
model.save('Sarcasm_Bert_Lstm.h5')

# %% [markdown]
# # Load the Model

# %%
loaded_model = load_model('Sarcasm_Bert_Lstm_MBSA_v2.h5')

# %% [markdown]
# # Making Predictions

# %%
def predict_sarcasm(s):
    x_final = pd.DataFrame({"headline":[s]})
    test_lines = CleanTokenize(x_final)
    test_sequences = tokenizer_obj.texts_to_sequences(test_lines)
    test_review_pad = pad_sequences(test_sequences, maxlen=max_length, padding='post')
    pred = loaded_model.predict(test_review_pad)
    pred*=100
    if pred[0][0]>=50: return "It's a sarcasm!" 
    else: return "It's not a sarcasm."

# %%
predict_sarcasm("I was depressed. He asked me to be happy. I am not depressed anymore.")
# Out:
# "It's a sarcasm!"

# %%
predict_sarcasm("You just broke my car window.Great job!!")
# Out:
# "It's not a sarcasm."

# %%
predict_sarcasm("You just broke my car window. good Boy!")
# Out:
# "It's not a sarcasm."

# %%
predict_sarcasm("You just saved my dog's life. Sorry.")
# Out:
# "It's not a sarcasm."

# %%
predict_sarcasm("I want a million dollars!")
# Out:
# "It's not a sarcasm."

# %%
predict_sarcasm("I just won a million dollars!")
# Out:
# "It's a sarcasm!"

# %%
predict_sarcasm("Hey Aniket, are you a boy??")
# Out:
# "It's not a sarcasm."
